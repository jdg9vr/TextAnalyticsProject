# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
DCM = pd.read_csv('./data/DCM.csv')
LOADINGS = pd.read_csv('./data/LOADINGS.csv')
VOCAB = pd.read_csv('./data/VOCAB.csv')
LOADINGS = LOADINGS.set_index('term_str')
VOCAB = VOCAB.set_index('term_str')

# %%
# PC0 is mostly about website related words
LOADINGS.sort_values('PC0', ascending=False)[:10]
# Out:
#                 PC0       PC1       PC2       PC3       PC4       PC5  \
# term_str
# cookies    0.306787 -0.114009 -0.556333 -0.022885  0.033709 -0.222410
# data       0.116660 -0.020076 -0.176131  0.012159 -0.003111  0.171392
# com        0.105064 -0.083138 -0.052709  0.068521 -0.135790 -0.042942
# privacy    0.103484 -0.053145 -0.154969  0.007732  0.005533  0.170015
# website    0.097390 -0.022469 -0.137956  0.084024  0.027145  0.183746
# web        0.095456 -0.026099 -0.159978  0.031940  0.018111 -0.022920
# site       0.093309  0.000175 -0.153378 -0.037992  0.017247 -0.059894
# rings      0.085628  0.006815 -0.021404 -0.136142  0.048373 -0.081080
# bearing    0.082892  0.002341  0.135186 -0.264072  0.521355  0.045722
# aerospace  0.077151 -0.047876  0.031492  0.113262  0.028587 -0.229235
#
#                 PC6       PC7       PC8       PC9
# term_str
# cookies   -0.023846 -0.026580  0.107694 -0.173745
# data       0.148281 -0.087311  0.056021  0.084159
# ...

# %%
# PC1 is mostly about production / maunfacture
LOADINGS.sort_values('PC1', ascending=False)[:10]
# Out:
#                 PC0       PC1       PC2       PC3       PC4       PC5  \
# term_str
# foundry   -0.180769  0.352463 -0.088104  0.028817 -0.071470 -0.070182
# bronze    -0.158602  0.322564 -0.096274 -0.044364 -0.071754  0.029436
# brass     -0.134475  0.271343 -0.082160 -0.283617 -0.069297 -0.129754
# sand      -0.219024  0.172548 -0.136148  0.188553  0.120701 -0.003231
# castings  -0.186802  0.129307 -0.137331  0.125058  0.086334  0.000050
# pattern   -0.082891  0.106895 -0.041339  0.030218  0.030083 -0.000908
# art       -0.027829  0.102535  0.013449  0.007703 -0.068901  0.045135
# copper    -0.022305  0.083612  0.007431 -0.089354 -0.057390 -0.023389
# co         0.014137  0.078572 -0.086913 -0.044117  0.026305 -0.036507
# aluminium -0.020495  0.076305  0.014349 -0.126456 -0.067998 -0.088819
#
#                 PC6       PC7       PC8       PC9
# term_str
# foundry   -0.117864 -0.082734  0.037684 -0.061149
# bronze    -0.007479 -0.142602  0.096630 -0.079521
# ...

# %%
# same for PC2 and PC3
LOADINGS.sort_values('PC2', ascending=False)[:10]
# Out:
#                    PC0       PC1       PC2       PC3       PC4       PC5  \
# term_str
# bearing       0.082892  0.002341  0.135186 -0.264072  0.521355  0.045722
# bearings      0.063941  0.010332  0.104162 -0.192800  0.411082  0.023548
# precision     0.011853 -0.063275  0.083566  0.086138  0.095897 -0.132956
# australia     0.043700  0.018006  0.075628  0.065767 -0.145362 -0.065125
# technologies  0.043348 -0.017239  0.066027  0.079252 -0.035066 -0.036790
# tool         -0.042105 -0.081160  0.064052  0.047583 -0.039780 -0.046957
# cnc          -0.042988 -0.068950  0.063241  0.164187  0.127865 -0.129059
# solutions    -0.026337 -0.038879  0.061791  0.068327  0.023590  0.012401
# ltd           0.012452 -0.044783  0.050245  0.097507 -0.211220 -0.221573
# development   0.027982 -0.023060  0.047460  0.072775 -0.005219 -0.024140
#
#                    PC6       PC7       PC8       PC9
# term_str
# bearing      -0.248859 -0.108451  0.205636  0.073526
# ...

# %%
LOADINGS.sort_values('PC3', ascending=False)[:10]
# Out:
#                  PC0       PC1       PC2       PC3       PC4       PC5  \
# term_str
# sand       -0.219024  0.172548 -0.136148  0.188553  0.120701 -0.003231
# cnc        -0.042988 -0.068950  0.063241  0.164187  0.127865 -0.129059
# castings   -0.186802  0.129307 -0.137331  0.125058  0.086334  0.000050
# machining  -0.062903 -0.058920 -0.029481  0.118986  0.091594 -0.064125
# aerospace   0.077151 -0.047876  0.031492  0.113262  0.028587 -0.229235
# milling    -0.006809 -0.011061  0.043501  0.109068  0.052791 -0.048875
# shell      -0.048422  0.030371 -0.043495  0.101441  0.057473  0.018435
# ltd         0.012452 -0.044783  0.050245  0.097507 -0.211220 -0.221573
# copyright  -0.037393  0.014434  0.042961  0.091937  0.004328 -0.012901
# industries -0.006199 -0.016334  0.023005  0.089900  0.086743 -0.021740
#
#                  PC6       PC7       PC8       PC9
# term_str
# sand       -0.102347  0.030471  0.054726  0.169531
# cnc         0.189941 -0.241323 -0.029526 -0.088941
# ...

# %% [markdown]
# # Visualize Loadings

# %%
def vis_loadings(a=0, b=1, hover_name='term_str'):
    X = LOADINGS.join(VOCAB)
    return px.scatter(X.reset_index(), f"PC{a}", f"PC{b}", 
                      text='term_str', size='i', color='max_pos',
                      marginal_x='box', height=800)

def vis_pcs(M, a, b, label='company_id', hover_name='company_id',symbol=None, size=None):
    fig = px.scatter(M, f"PC{a}", f"PC{b}", hover_name=hover_name, 
                     symbol=symbol, size=size,
                     marginal_x='box', height=800)
    fig.show()

# %%
vis_pcs(DCM, 0, 1)

# %%
vis_loadings(0, 1)
